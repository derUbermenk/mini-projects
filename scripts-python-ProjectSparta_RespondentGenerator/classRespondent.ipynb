# %%
class Respondent:
    
    budgetAllocation ={food, house/rent, utilities, transport, communication, education, health, clothing, savings, others}
    
    def __init__(self):
        self.region = setRegion(self)
        self.budgetAllocation = 
        self.salaryContemporary = setSalaryContemporary(self.region)
        self.salaryPrePandemic = setSalaryPrePandemic(self.salaryContemporary)
        self.familySize = 
        self.numEmployed_Contemporary =
        self.numUnEmp_contem =
        self.numEmployed_pre = 
        self.numUnEmp_pre =
        self.numStudents =
        
    
    def assignRegion(self):
        import numpy.random
        regionsList = ['Region V - Bicol Region', 'NCR - National Capital Region', 'Region III - Central Luzon', 
                       'Region VII - Central Visayas', 'Region IVA - CALABARZON', 
                       'CAR - Cordillera Administrative Region', 'Region I - Ilocos Region']
        
        regionDistribution = [0.28, 0.28, 0.19, 0.03, 0.16, 0.03, 0.03]
        
        return numpy.random.choice(regionsList,p = regionDistribution)
    
    def setSalaryContemporary(self, self.region):
        salaries = [3500, 13500, 23000, 32500, 41500, 47500, 6000, 72500, 80000]
        regions = {'CAR - Cordillera Administrative Region': [.2,0.18,0.17,0.32,0.05,0.001,0.01,0.05,0.016,0.002,0.001],
                   'NCR - National Capital Region': [.06,0.111111111,0.133333333,0.222222222,0.31,0.1,0.04,0.01,0.001,0.002,0.01],
                   'Region I - Ilocos Region': [0.111111111,0.09,0.11,0.2972,0.11,0.11,0.07,0.08,0.02,0.001,0.001],
                   'Region IVA - CALABARZON': [0.01,0.05,0.11,0.2,0.365,0.13,0.11,0.02,0.001,0.003,0.001],
                   'Region V - Bicol Region': [0.11,0.11,0.11,0.22,0.08,0.02,0.11,0.01,0.02,0.2,0.01],
                   'Region VII - Central Visayas': [0.01,0.35,0.26,0.18,0.11,0.05,0.02,0,0.001,0.009,0.01]}
        
        for key in regions:
            if key == self.region:
                salaryProbabilities = regions[key]
                salaryPresent = numpy.random.choice(salaries, p = salaryProbabilities)
                return salaryPresent
        
    def setSalaryPrePandemic(self, self.contemporary):
        increment = [-50, 500, 1000, 5000, 50000,25000,30000]
        incrementProb = [0.05, 0.5, 0.225, 0.225, 0.01,0.02, 0.03]
        salaryPre = self.salaryContemporary + numpy.random.choice(increment, p = incrementProb)
        return salaryPre
    
    def  setBudgetAllocation(self):
        #pano?
        #plano muna sa Lucid Chart!

# %%
#inc is increment

Fam Demog

    def FamilySize(self, takes in salary):
        size(2,3,4,5,6)
        
        if salary > 31000
            prob = (0.1,0.4,0.3,0.1,0.1)
            familysiz = euseNumpyrandomchoice shit with size as choices, prob as weights
            return familysize
        elif salary is <= 31000:
            prob = (0.05,0.1,0.15,0.5,0.2,0.1)
            familysize = useNumpyrandomchoice shit with size as choices, prob as weights
            return familysize
    def numStuds(self,famSize):
        #Dependency ratio in ph is 55%
        ageDependency ratio + inc|such that inc varies from +/- in range 0-6
        ()
        increments = list of ranges 
        probabilities is that yung increment na pinakamalapit sa 0 is good,vary by 5
        do something| famSize *ageDependencty ratio = numStudents | numstudents must not equal famSize paground ko 
        #ilagay kaya natin sa while loop to| pag oo na return that value.
        return numStudents
    def numEmp_prePandemic(self,famsize):
        numEmp = famSize - numStudents - Unemp#get in range (1 to (famsize - numStudents)
        return numEmp
    def numUnemp_prePandemic(self, number of employed prepandemic, Famsize, students  ):
        numEmp = famsize -(numEmp + students)
        
    def numEmp_contemp(self, numEmpContempory)
        numEmp = numEmpCotempo + range(0,-2)
    def numUnemp_present(self, numEmpPresent):
        numemp = familySize - (numEmpPresent + numStudents)
    
        
        
        
#get budget allocation
#this is at current figures

    define salary = self.salaryPre
    avgIncome = 31,000
    #average budget allocation as init values
    #solve for budget allocations
    #food
    Food
        define getInc(takes in salary):
            #note on lerping in phyton;
            '''def lerp(v, d):
                    return v[0] * (1 - d) + v[1] * d'''
            #where v is a tuple|v[0] is init(lerpVal @ 0) and v[1] is max(lerpVal @ 1)

            if salary is >= 31,000:
                inc = do some lerp with range(31000,150000) * 0.1
                
            elif salary < 31,000:
                inc = -1 * (do some lerp with range(3500,30999) * 0.1
                



        budgetAllocation[food] =  respondent.averageBudgetLocation[food] + inc
        return budgetAllocation

   
    house/rent(income,regionBased)
            evaluate increment percentage based on income:
            increment based on income = range(-0.07-0.07)
            increment based on region = range(-0.05-0.05)
            allocation = avgbudgetAllocation + incrementbasedOnIncome +Region
            returnAllocation

    utilities(income,familyBased)#increase with income and numFamMembers
            increment)
            
            do the same thing with house/rent allocation, change values slightly
            
    transport(regionDependent)
    
            regions {roup the regions: [possible increments]}
            find the region of respondent in the regions group:
                if the region of that respondent corrresponds to the currentItem get value
                allocation = avgBudgetAllocation + increment
                return allocation
    
    communication(increase with salary)
                
                
                get the salary  of the respondent
                if salary is >= 31,000:
                    inc = do some lerp with range(31000,150000) * 0.05
                    return inc
                elif salary < 31,000:
                    inc = -1 * (do some lerp with range(3500,30999) * 0.05
                    return inc
                
                allocation = avgBudgetallocationfor Category + inc

    
    education(increase with salary and relate to fam Demog)
                get salary and numStudents
                
                
                if salary is >= 31,000:
                    salartyInc  = do some lerp with range(31000,150000) * 0.02
                     SalaryInc
                elif salary < 31,000:
                    salartyInc = -1 * (do some lerp with range(3500,30999) * 0.02
                     salaryInc
                
                numStudentIncrement = use inverseLerp| values((0,6)numstudents)* 0.4
                budgetAllocation = salaryInc +numStudentInc AverageBudgetAllocation for this category
                return budgetAllocation
                
    
    savings(0.1 nung budget yung average)
            0.1 + increment sa range na (-0.03 to 0.03)
            return allocation

    others(salary related)
        get salary of respondent 
           if salary is >= 31,000:
                    salartyInc  = do some lerp with range(31000,150000) * 0.06
                    return SalaryInc
                elif salary < 31,000:
                    salartyInc = -1 * (do some lerp with range(3500,30999) * 0.06
                    return salaryInc
                
                budgetAllocation = averegae nung budget + increment 
                return budgetAllocation
